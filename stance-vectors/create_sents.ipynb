# %%
import pandas as pd

from nltk import sent_tokenize

# %%
tdf = pd.read_csv('../working-csvs/fomc_sectioned.csv', index_col=0)

# %%
sg = tdf.groupby(['lname', 'date', 'section'])['content'].agg(' '.join).reset_index()

# %%
sg['sentences'] = sg['content'].map(sent_tokenize)
sg.drop(['content'], axis=1, inplace=True)
sgs = sg.explode('sentences')
sgs.rename(columns={'sentences': 'content'}, inplace=True)

# %%
sgs
# Out:
#          lname        date  section  \
# 0     bernanke  2002-08-13        1
# 0     bernanke  2002-08-13        1
# 0     bernanke  2002-08-13        1
# 0     bernanke  2002-08-13        1
# 0     bernanke  2002-08-13        1
# ...        ...         ...      ...
# 6701    yellen  2018-01-31        2
# 6701    yellen  2018-01-31        2
# 6701    yellen  2018-01-31        2
# 6701    yellen  2018-01-31        2
# 6701    yellen  2018-01-31        2
#
#                                                 content
# 0                              Thank you, Mr. Chairman.
# 0     As we search for the signal of an incipient re...
# 0     The first source of noise is the financial mar...
# 0     Our financial markets usually exhibit controll...
# 0     The stock market in particular seems to be sea...
# ...                                                 ...
# 6701                                  Further comments?
# 6701                                              Okay.
# 6701  Well, hearing this discussion, I think my incl...
# 6701  I recognize that there is some risk in doing i...
# 6701  So let me ask Jim Clouse to make clear what th...
#
# [260807 rows x 4 columns]

# %%
sgs.reset_index(drop=True)
# Out:
#            lname        date  section  \
# 0       bernanke  2002-08-13        1
# 1       bernanke  2002-08-13        1
# 2       bernanke  2002-08-13        1
# 3       bernanke  2002-08-13        1
# 4       bernanke  2002-08-13        1
# ...          ...         ...      ...
# 260802    yellen  2018-01-31        2
# 260803    yellen  2018-01-31        2
# 260804    yellen  2018-01-31        2
# 260805    yellen  2018-01-31        2
# 260806    yellen  2018-01-31        2
#
#                                                   content
# 0                                Thank you, Mr. Chairman.
# 1       As we search for the signal of an incipient re...
# 2       The first source of noise is the financial mar...
# 3       Our financial markets usually exhibit controll...
# 4       The stock market in particular seems to be sea...
# ...                                                   ...
# 260802                                  Further comments?
# 260803                                              Okay.
# 260804  Well, hearing this discussion, I think my incl...
# 260805  I recognize that there is some risk in doing i...
# 260806  So let me ask Jim Clouse to make clear what th...
#
# [260807 rows x 4 columns]

# %%
sgs.to_csv('../working-csvs/fomc_sents.csv')
